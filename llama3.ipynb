# %%
# %pip install -r requirements.txt
# Out:
# Collecting accelerate==0.30.1 (from -r requirements.txt (line 1))
#   Downloading accelerate-0.30.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: bitsandbytes==0.43.1 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from -r requirements.txt (line 2)) (0.43.1)
# Collecting transformers==4.41.0 (from -r requirements.txt (line 3))
#   Downloading transformers-4.41.0-py3-none-any.whl.metadata (43 kB)
#      ---------------------------------------- 0.0/43.8 kB ? eta -:--:--
#      ---------------------------------------- 43.8/43.8 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from accelerate==0.30.1->-r requirements.txt (line 1)) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from accelerate==0.30.1->-r requirements.txt (line 1)) (23.2)
# Requirement already satisfied: psutil in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from accelerate==0.30.1->-r requirements.txt (line 1)) (5.9.8)
# Requirement already satisfied: pyyaml in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from accelerate==0.30.1->-r requirements.txt (line 1)) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from accelerate==0.30.1->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: huggingface-hub in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from accelerate==0.30.1->-r requirements.txt (line 1)) (0.23.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from accelerate==0.30.1->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: filelock in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from transformers==4.41.0->-r requirements.txt (line 3)) (3.14.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from transformers==4.41.0->-r requirements.txt (line 3)) (2024.4.28)
# Requirement already satisfied: requests in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from transformers==4.41.0->-r requirements.txt (line 3)) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from transformers==4.41.0->-r requirements.txt (line 3)) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from transformers==4.41.0->-r requirements.txt (line 3)) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from huggingface-hub->accelerate==0.30.1->-r requirements.txt (line 1)) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from huggingface-hub->accelerate==0.30.1->-r requirements.txt (line 1)) (4.11.0)
# Requirement already satisfied: sympy in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from torch>=1.10.0->accelerate==0.30.1->-r requirements.txt (line 1)) (1.12)
# Requirement already satisfied: networkx in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from torch>=1.10.0->accelerate==0.30.1->-r requirements.txt (line 1)) (3.3)
# Requirement already satisfied: jinja2 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from torch>=1.10.0->accelerate==0.30.1->-r requirements.txt (line 1)) (3.1.3)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from torch>=1.10.0->accelerate==0.30.1->-r requirements.txt (line 1)) (2021.4.0)
# Requirement already satisfied: colorama in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from tqdm>=4.27->transformers==4.41.0->-r requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from requests->transformers==4.41.0->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from requests->transformers==4.41.0->-r requirements.txt (line 3)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from requests->transformers==4.41.0->-r requirements.txt (line 3)) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from requests->transformers==4.41.0->-r requirements.txt (line 3)) (2024.2.2)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->accelerate==0.30.1->-r requirements.txt (line 1)) (2021.4.0)
# Requirement already satisfied: tbb==2021.* in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch>=1.10.0->accelerate==0.30.1->-r requirements.txt (line 1)) (2021.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from jinja2->torch>=1.10.0->accelerate==0.30.1->-r requirements.txt (line 1)) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in c:\users\z003zt8j\appdata\local\miniconda3\envs\myenvforgenai\lib\site-packages (from sympy->torch>=1.10.0->accelerate==0.30.1->-r requirements.txt (line 1)) (1.3.0)
# Downloading accelerate-0.30.1-py3-none-any.whl (302 kB)
#    ---------------------------------------- 0.0/302.6 kB ? eta -:--:--
#    ---------- ----------------------------- 81.9/302.6 kB 2.3 MB/s eta 0:00:01
#    ------------------------ --------------- 184.3/302.6 kB 2.2 MB/s eta 0:00:01
#    ------------------------------------- -- 286.7/302.6 kB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 302.6/302.6 kB 1.9 MB/s eta 0:00:00
# Downloading transformers-4.41.0-py3-none-any.whl (9.1 MB)
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#    ---------------------------------------- 0.1/9.1 MB 1.6 MB/s eta 0:00:06
#     --------------------------------------- 0.2/9.1 MB 1.8 MB/s eta 0:00:05
#     --------------------------------------- 0.2/9.1 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/9.1 MB 1.8 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/9.1 MB 1.8 MB/s eta 0:00:05
#    -- ------------------------------------- 0.5/9.1 MB 1.9 MB/s eta 0:00:05
#    -- ------------------------------------- 0.6/9.1 MB 1.9 MB/s eta 0:00:05
#    -- ------------------------------------- 0.6/9.1 MB 1.8 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/9.1 MB 1.8 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/9.1 MB 1.8 MB/s eta 0:00:05
#    --- ------------------------------------ 0.9/9.1 MB 1.8 MB/s eta 0:00:05
#    ---- ----------------------------------- 0.9/9.1 MB 1.8 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/9.1 MB 1.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 1.0/9.1 MB 1.6 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/9.1 MB 1.5 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/9.1 MB 1.5 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.1/9.1 MB 1.4 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.1/9.1 MB 1.3 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.1/9.1 MB 1.3 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.1/9.1 MB 1.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.2/9.1 MB 1.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.2/9.1 MB 1.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.3/9.1 MB 1.2 MB/s eta 0:00:07
#    ------ --------------------------------- 1.4/9.1 MB 1.3 MB/s eta 0:00:07
#    ------ --------------------------------- 1.5/9.1 MB 1.3 MB/s eta 0:00:06
#    ------ --------------------------------- 1.5/9.1 MB 1.3 MB/s eta 0:00:06
#    ------- -------------------------------- 1.6/9.1 MB 1.3 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.1 MB 1.4 MB/s eta 0:00:06
#    -------- ------------------------------- 1.8/9.1 MB 1.4 MB/s eta 0:00:06
#    -------- ------------------------------- 1.9/9.1 MB 1.4 MB/s eta 0:00:06
#    -------- ------------------------------- 2.0/9.1 MB 1.4 MB/s eta 0:00:06
#    -------- ------------------------------- 2.0/9.1 MB 1.4 MB/s eta 0:00:06
#    --------- ------------------------------ 2.1/9.1 MB 1.4 MB/s eta 0:00:06
#    --------- ------------------------------ 2.2/9.1 MB 1.4 MB/s eta 0:00:06
#    --------- ------------------------------ 2.2/9.1 MB 1.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.3/9.1 MB 1.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.4/9.1 MB 1.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.5/9.1 MB 1.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.5/9.1 MB 1.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.5/9.1 MB 1.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.6/9.1 MB 1.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.7/9.1 MB 1.4 MB/s eta 0:00:05
#    ------------ --------------------------- 2.8/9.1 MB 1.4 MB/s eta 0:00:05
#    ------------ --------------------------- 2.9/9.1 MB 1.4 MB/s eta 0:00:05
#    ------------ --------------------------- 2.9/9.1 MB 1.4 MB/s eta 0:00:05
#    ------------- -------------------------- 3.1/9.1 MB 1.4 MB/s eta 0:00:05
#    ------------- -------------------------- 3.1/9.1 MB 1.4 MB/s eta 0:00:05
#    -------------- ------------------------- 3.2/9.1 MB 1.5 MB/s eta 0:00:04
#    -------------- ------------------------- 3.3/9.1 MB 1.5 MB/s eta 0:00:04
#    -------------- ------------------------- 3.4/9.1 MB 1.5 MB/s eta 0:00:04
#    --------------- ------------------------ 3.4/9.1 MB 1.5 MB/s eta 0:00:04
#    --------------- ------------------------ 3.5/9.1 MB 1.5 MB/s eta 0:00:04
#    --------------- ------------------------ 3.6/9.1 MB 1.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.7/9.1 MB 1.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.7/9.1 MB 1.5 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.8/9.1 MB 1.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 3.9/9.1 MB 1.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.0/9.1 MB 1.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.1/9.1 MB 1.5 MB/s eta 0:00:04
#    ------------------ --------------------- 4.1/9.1 MB 1.5 MB/s eta 0:00:04
#    ------------------ --------------------- 4.2/9.1 MB 1.5 MB/s eta 0:00:04
#    ------------------ --------------------- 4.3/9.1 MB 1.5 MB/s eta 0:00:04
#    ------------------- -------------------- 4.4/9.1 MB 1.5 MB/s eta 0:00:04
#    ------------------- -------------------- 4.5/9.1 MB 1.5 MB/s eta 0:00:04
#    ------------------- -------------------- 4.5/9.1 MB 1.5 MB/s eta 0:00:04
#    ------------------- -------------------- 4.5/9.1 MB 1.5 MB/s eta 0:00:04
#    ------------------- -------------------- 4.5/9.1 MB 1.5 MB/s eta 0:00:04
#    ------------------- -------------------- 4.5/9.1 MB 1.5 MB/s eta 0:00:04
#    ------------------- -------------------- 4.5/9.1 MB 1.4 MB/s eta 0:00:04
#    ------------------- -------------------- 4.5/9.1 MB 1.4 MB/s eta 0:00:04
#    ------------------- -------------------- 4.5/9.1 MB 1.4 MB/s eta 0:00:04
#    -------------------- ------------------- 4.6/9.1 MB 1.4 MB/s eta 0:00:04
#    -------------------- ------------------- 4.6/9.1 MB 1.4 MB/s eta 0:00:04
#    -------------------- ------------------- 4.7/9.1 MB 1.4 MB/s eta 0:00:04
#    --------------------- ------------------ 4.8/9.1 MB 1.4 MB/s eta 0:00:04
#    --------------------- ------------------ 4.8/9.1 MB 1.4 MB/s eta 0:00:04
#    --------------------- ------------------ 4.9/9.1 MB 1.4 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.0/9.1 MB 1.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.1/9.1 MB 1.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.2/9.1 MB 1.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.3/9.1 MB 1.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.4/9.1 MB 1.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.4/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------ --------------- 5.6/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------ --------------- 5.6/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.7/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.8/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.8/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.8/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.8/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.8/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.8/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.9/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.9/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.9/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.9/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.9/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.9/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.9/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.9/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.9/9.1 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 5.9/9.1 MB 1.4 MB/s eta 0:00:03
#    -------------------------- ------------- 6.0/9.1 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 6.1/9.1 MB 1.3 MB/s eta 0:00:03
#    -------------------------- ------------- 6.1/9.1 MB 1.2 MB/s eta 0:00:03
#    -------------------------- ------------- 6.1/9.1 MB 1.2 MB/s eta 0:00:03
#    -------------------------- ------------- 6.1/9.1 MB 1.2 MB/s eta 0:00:03
#    --------------------------- ------------ 6.2/9.1 MB 1.2 MB/s eta 0:00:03
#    --------------------------- ------------ 6.3/9.1 MB 1.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 6.4/9.1 MB 1.2 MB/s eta 0:00:03
#    ---------------------------- ----------- 6.5/9.1 MB 1.3 MB/s eta 0:00:03
#    ----------------------------- ---------- 6.6/9.1 MB 1.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.7/9.1 MB 1.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.8/9.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 6.9/9.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------------ --------- 7.0/9.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 7.1/9.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 7.1/9.1 MB 1.3 MB/s eta 0:00:02
#    ------------------------------- -------- 7.2/9.1 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 7.3/9.1 MB 1.3 MB/s eta 0:00:02
#    -------------------------------- ------- 7.4/9.1 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 7.5/9.1 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 7.6/9.1 MB 1.3 MB/s eta 0:00:02
#    --------------------------------- ------ 7.7/9.1 MB 1.3 MB/s eta 0:00:02
#    ---------------------------------- ----- 7.8/9.1 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.9/9.1 MB 1.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.0/9.1 MB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.1/9.1 MB 1.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.2/9.1 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 8.3/9.1 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 8.3/9.1 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 8.4/9.1 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 8.5/9.1 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 8.6/9.1 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 8.7/9.1 MB 1.4 MB/s eta 0:00:01
#    -------------------------------------- - 8.8/9.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  8.9/9.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  9.0/9.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  9.0/9.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  9.1/9.1 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.1/9.1 MB 1.4 MB/s eta 0:00:00
# Installing collected packages: accelerate, transformers
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.30.0
#     Uninstalling accelerate-0.30.0:
#       Successfully uninstalled accelerate-0.30.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.40.2
#     Uninstalling transformers-4.40.2:
#       Successfully uninstalled transformers-4.40.2
# Successfully installed accelerate-0.30.1 transformers-4.41.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import torch
from transformers import (AutoTokenizer, 
                          AutoModelForCausalLM,
                          BitsAndBytesConfig,
                          pipeline)

# %%
config_data=json.load(open("config.json"))
HF_TOKEN=config_data["HF_TOKEN"]
print(HF_TOKEN)
# Out:
# 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

# %%
model_name = "meta-llama/Meta-Llama-3-8B"

# %% [markdown]
# # Quantisation Configuration

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16
)

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name,
                                          token=HF_TOKEN)

tokenizer.pad_token = tokenizer.eos_token
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    quantization_config=bnb_config,
    token=HF_TOKEN
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model = AutoModelForCausalLM.from_pretrained(
#       2     model_name,
#       3     device_map="auto",
#       4     quantization_config=bnb_config,
#       5     token=HF_TOKEN
#       6 )
#
# File c:\Users\z003zt8j\AppData\Local\miniconda3\envs\myEnvForGenAI\Lib\site-packages\transformers\models\auto\auto_factory.py:563, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561 elif type(config) in cls._model_mapping.keys():
#     562     model_class = _get_model_class(config, cls._model_mapping)
# --> 563     return model_class.from_pretrained(
#     564         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     565     )
#     566 raise ValueError(
#     567     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     568     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     569 )
#
# File c:\Users\z003zt8j\AppData\Local\miniconda3\envs\myEnvForGenAI\Lib\site-packages\transformers\modeling_utils.py:3202, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3199     hf_quantizer = None
#    3201 if hf_quantizer is not None:
# -> 3202     hf_quantizer.validate_environment(
#    3203         torch_dtype=torch_dtype, from_tf=from_tf, from_flax=from_flax, device_map=device_map
#    3204     )
#    3205     torch_dtype = hf_quantizer.update_torch_dtype(torch_dtype)
#    3206     device_map = hf_quantizer.update_device_map(device_map)
#
# File c:\Users\z003zt8j\AppData\Local\miniconda3\envs\myEnvForGenAI\Lib\site-packages\transformers\quantizers\quantizer_bnb_4bit.py:62, in Bnb4BitHfQuantizer.validate_environment(self, *args, **kwargs)
#      60 def validate_environment(self, *args, **kwargs):
#      61     if not torch.cuda.is_available():
# ---> 62         raise RuntimeError("No GPU found. A GPU is needed for quantization.")
#      63     if not (is_accelerate_available() and is_bitsandbytes_available()):
#      64         raise ImportError(
#      65             "Using `bitsandbytes` 8-bit quantization requires Accelerate: `pip install accelerate` "
#      66             "and the latest version of bitsandbytes: `pip install -i https://pypi.org/simple/ bitsandbytes`"
#      67         )
#
# RuntimeError: No GPU found. A GPU is needed for quantization.
